# %%
import numpy as np
import pandas as pd 
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Reading Data

# %%
swiggy_df = pd.read_csv('C:/Users/Admin/Desktop/Raghav folder/I neuron Internshp/DATA/Swiggy Bangalore Outlet Details.csv')

# %%
swiggy_df
# Out:
#               Shop_Name                                            Cuisine  \
# 0          Kanti Sweets                                             Sweets
# 1         Mumbai Tiffin             North Indian, Home Food, Thalis, Combo
# 2     Sri Krishna sagar  South Indian, North Indian, Fast Food, Beverag...
# 3               Al Daaz  American, Arabian, Chinese, Desserts, Fast Foo...
# 4         Beijing Bites                                      Chinese, Thai
# ..                  ...                                                ...
# 113  Wok Paper Scissors                          Pan-Asian, Chinese, Asian
# 114  Savoury Restaurant  Arabian, Middle Eastern, North Indian, Grill, ...
# 115         Royal Treat            North Indian, Chinese, Seafood, Biryani
# 116            Thali 99                                       North Indian
# 117  Mani's Dum Biryani                                    Andhra, Biryani
#
#                                Location Rating Cost_for_Two
# ...

# %%
swiggy_df.describe()
# Out:
#               Shop_Name       Cuisine  Location Rating Cost_for_Two
# count               118           118       118    118          118
# unique              115            79        65     13           30
# top     La Pino'z Pizza  North Indian  BTM, BTM    4.1        ₹ 300
# freq                  2            12        13     30           16

# %% [markdown]
#  Most liked Shop Name : Easy Bites
#
#  Most liked Cuisine : North Indian

# %%
swiggy_df.columns
# Out:
# Index(['Shop_Name', 'Cuisine', 'Location', 'Rating', 'Cost_for_Two'], dtype='object')

# %% [markdown]
# To Get information of columns

# %%
swiggy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Shop_Name     118 non-null    object
#  1   Cuisine       118 non-null    object
#  2   Location      118 non-null    object
#  3   Rating        118 non-null    object
#  4   Cost_for_Two  118 non-null    object
# dtypes: object(5)
# memory usage: 4.7+ KB

# %% [markdown]
# # Calculate how many rows and columns in dataset

# %%
swiggy_df.shape
# Out:
# (118, 5)

# %% [raw]
# rows in swiggy_df

# %%
swiggy_df.shape[0]
# Out:
# 118

# %% [raw]
# columns in swiggy_df

# %%
swiggy_df.shape[1]
# Out:
# 5

# %% [markdown]
# # Data Cleaning and Preprocessing

# %% [raw]
# Check there is any duplicated row or not

# %%
swiggy_df.duplicated().sum()
# Out:
# 0

# %% [raw]
# Checking Numerical Data

# %% [markdown]
# 1) Rating column

# %%
swiggy_df['Rating'].unique()
# Out:
# array(['4.3', '4.4', '4.1', '4.2', '3.9', '3.8', '4', '3.7', '3.6', '4.8',
#        '4.5', '4.6', '--'], dtype=object)

# %%
# Changing '--' to '0'

# %%
swiggy_df['Rating']= swiggy_df['Rating'].str.replace('--', '0').astype(float)

# %%
swiggy_df.Rating.unique()
# Out:
# array([4.3, 4.4, 4.1, 4.2, 3.9, 3.8, 4. , 3.7, 3.6, 4.8, 4.5, 4.6, 0. ])

# %% [markdown]
# 2) Cost For Two

# %%
swiggy_df['Cost_for_Two'].unique()
# Out:
# array(['₹ 150', '₹ 400', '₹ 126', '₹ 450', '₹ 350', '₹ 200', '₹ 500',
#        '₹ 247', '₹ 550', '₹ 300', '₹ 129', '₹ 250', '₹ 268', '₹ 600',
#        '₹ 527', '₹ 130', '₹ 257', '₹ 280', '₹ 399', '₹ 220', '₹ 800',
#        '₹ 100', '₹ 178', '₹ 120', '₹ 251', '₹ 650', '₹ 132', '₹ 153',
#        '₹ 219', '₹ 193'], dtype=object)

# %%
obj = lambda x: x[1:]

# %%
swiggy_df['Cost_for_Two (in Rupees)']= swiggy_df['Cost_for_Two'].apply(obj).astype('int32')

# %%
swiggy_df
# Out:
#               Shop_Name                                            Cuisine  \
# 0          Kanti Sweets                                             Sweets
# 1         Mumbai Tiffin             North Indian, Home Food, Thalis, Combo
# 2     Sri Krishna sagar  South Indian, North Indian, Fast Food, Beverag...
# 3               Al Daaz  American, Arabian, Chinese, Desserts, Fast Foo...
# 4         Beijing Bites                                      Chinese, Thai
# ..                  ...                                                ...
# 113  Wok Paper Scissors                          Pan-Asian, Chinese, Asian
# 114  Savoury Restaurant  Arabian, Middle Eastern, North Indian, Grill, ...
# 115         Royal Treat            North Indian, Chinese, Seafood, Biryani
# 116            Thali 99                                       North Indian
# 117  Mani's Dum Biryani                                    Andhra, Biryani
#
#                                Location  Rating Cost_for_Two  \
# ...

# %%
swiggy_df = swiggy_df.drop('Cost_for_Two',axis=1)

# %%
swiggy_df['Cost_for_Two (in Rupees)'].unique()
# Out:
# array([150, 400, 126, 450, 350, 200, 500, 247, 550, 300, 129, 250, 268,
#        600, 527, 130, 257, 280, 399, 220, 800, 100, 178, 120, 251, 650,
#        132, 153, 219, 193])

# %% [markdown]
# # Observation

# %% [raw]
#  Cost_For_two vs Total Bill count

# %%
sns.histplot(swiggy_df['Cost_for_Two (in Rupees)'])
# Out:
# <AxesSubplot:xlabel='Cost_for_Two (in Rupees)', ylabel='Count'>

# %% [raw]
# With Increasing Cost_For_Two the bill Count Decrease

# %% [markdown]
# Rating vs Restaurant count

# %%
a= swiggy_df.Rating.value_counts().reset_index()
a
# Out:
#     index  Rating
# 0     4.1      30
# 1     4.3      23
# 2     4.0      21
# 3     3.9      13
# 4     4.2      10
# 5     3.7       6
# 6     3.8       4
# 7     4.4       4
# 8     4.6       2
# 9     3.6       2
# 10    0.0       1
# 11    4.8       1
# 12    4.5       1

# %%
sns.barplot(data =a,x='index',y='Rating')
plt.xlabel('Rating-------->')
plt.ylabel('Count-------->')
# Out:
# Text(0, 0.5, 'Count-------->')

# %% [raw]
#  This shows that value '4.1' has most given to most number of restaurants

# %% [raw]
# It is type of normal distribution curve

# %% [markdown]
# Location

# %%
swiggy_df['Location'].unique()
# Out:
# array(['Koramangala, Koramangala', 'Sector 5, HSR',
#        '6th Block, Koramangala', 'HSR, HSR', '5th Block, Koramangala',
#        'Koramangala 4th  Block, Koramangala', 'BTM 2nd Stage, BTM',
#        'BTM, BTM', '9th Main road, Koramangala', 'outer ring road, BTM',
#        '7th Block, Koramangala', '1st MAin, Koramangala',
#        'Bommanahalli, BTM', '6th block, Koramangala', 'Sector 4, HSR',
#        'BTM 1st stage, BTM', 'Jakkasandra Extn, Koramangala',
#        'Marutinagar Main Road, BTM', '1st Block, Koramangala',
#        '4th Cross, BTM', 'koramangala, Koramangala', 'BTM 2nd stage, BTM',
#        '3rd main, BTM', 'HSR 1st sector, HSR', 'Sector 7, HSR',
#        '3rd Sector, HSR', 'Chocolate Factory Road, BTM',
#        '16th Main Road, 2nd Stage, BTM', '1st Stage, BTM',
#        'Hosur Main Road, Koramangala',
#        '1st Cross Road, 5th Block, Near Jyothi Nivas College, Koramangala',
#        'Mico Layout, BTM', '4th Cross, Koramangala',
# ...

# %%
b = swiggy_df['Location'].str.split(pat=',').reset_index()
b
# Out:
#      index                               Location
# 0        0            [Koramangala,  Koramangala]
# 1        1                       [Sector 5,  HSR]
# 2        2              [6th Block,  Koramangala]
# 3        3                            [HSR,  HSR]
# 4        4              [5th Block,  Koramangala]
# ..     ...                                    ...
# 113    113               [JNC Road,  Koramangala]
# 114    114                       [Madiwala,  BTM]
# 115    115  [5th block Koramangala,  Koramangala]
# 116    116            [Koramangala,  Koramangala]
# 117    117              [1st Block,  Koramangala]
#
# [118 rows x 2 columns]

# %%
obj1 = lambda x:x[-1]

# %%
b['Location'] = b['Location'].apply(obj1)
b
# Out:
#      index      Location
# 0        0   Koramangala
# 1        1           HSR
# 2        2   Koramangala
# 3        3           HSR
# 4        4   Koramangala
# ..     ...           ...
# 113    113   Koramangala
# 114    114           BTM
# 115    115   Koramangala
# 116    116   Koramangala
# 117    117   Koramangala
#
# [118 rows x 2 columns]

# %%
b.rename({'Location':'City Name'},axis=1,inplace = True)

# %%
b
# Out:
#      index     City Name
# 0        0   Koramangala
# 1        1           HSR
# 2        2   Koramangala
# 3        3           HSR
# 4        4   Koramangala
# ..     ...           ...
# 113    113   Koramangala
# 114    114           BTM
# 115    115   Koramangala
# 116    116   Koramangala
# 117    117   Koramangala
#
# [118 rows x 2 columns]

# %%
swiggy_df['City']= b['City Name']

# %%
swiggy_df
# Out:
#               Shop_Name                                            Cuisine  \
# 0          Kanti Sweets                                             Sweets
# 1         Mumbai Tiffin             North Indian, Home Food, Thalis, Combo
# 2     Sri Krishna sagar  South Indian, North Indian, Fast Food, Beverag...
# 3               Al Daaz  American, Arabian, Chinese, Desserts, Fast Foo...
# 4         Beijing Bites                                      Chinese, Thai
# ..                  ...                                                ...
# 113  Wok Paper Scissors                          Pan-Asian, Chinese, Asian
# 114  Savoury Restaurant  Arabian, Middle Eastern, North Indian, Grill, ...
# 115         Royal Treat            North Indian, Chinese, Seafood, Biryani
# 116            Thali 99                                       North Indian
# 117  Mani's Dum Biryani                                    Andhra, Biryani
#
# ...

# %%
swiggy_df.City.unique()
# Out:
# array([' Koramangala', ' HSR', ' BTM', ' Jayanagar'], dtype=object)

# %%
sns.countplot(data = swiggy_df  ,x = 'City')
plt.ylabel('Total number of restaurants')
# Out:
# Text(0, 0.5, 'Total number of restaurants')

# %%
# Checking how many unique value

# %%
swiggy_df['Location'].nunique()
# Out:
# 65

# %% [markdown]
# There are three main regions in data

# %%
swiggy_Koramangala = swiggy_df[swiggy_df['Location'].str.contains(r'Koramangala')]
swiggy_Koramangala
# Out:
#               Shop_Name                                            Cuisine  \
# 0          Kanti Sweets                                             Sweets
# 2     Sri Krishna sagar  South Indian, North Indian, Fast Food, Beverag...
# 4         Beijing Bites                                      Chinese, Thai
# 5    Kitchens of Punjab                                       North Indian
# 9         Yumlane Pizza                           Pizzas, Italian, Mexican
# ..                  ...                                                ...
# 112            Kritunga                                    Andhra, Biryani
# 113  Wok Paper Scissors                          Pan-Asian, Chinese, Asian
# 115         Royal Treat            North Indian, Chinese, Seafood, Biryani
# 116            Thali 99                                       North Indian
# 117  Mani's Dum Biryani                                    Andhra, Biryani
#
# ...

# %%
swiggy_HSR = swiggy_df[swiggy_df['Location'].str.contains(r'HSR')]
swiggy_HSR
# Out:
#                           Shop_Name  \
# 1                     Mumbai Tiffin
# 3                           Al Daaz
# 8                        Hotel Manu
# 19              Shree Khana Khazana
# 24                  New Udupi Grand
# 36                    Biriyani Zone
# 37                        Gongura's
# 39                       Leon Grill
# 41                         Cakewala
# 57             Donne Biriyani House
# 58                          Nanda's
# 61                      Cake Garden
# 71                   Nizams Biryani
# 73                    Punjabi Rasoi
# 98      Mandya Gowdru Donne Biryani
# 99   Dindigul Thalapakatti Biriyani
# 101                      Easy Bites
# 107                 Junior Kuppanna
#
#                                                Cuisine  \
# 1               North Indian, Home Food, Thalis, Combo
# 3    American, Arabian, Chinese, Desserts, Fast Foo...
# 8          South Indian, Kerala, Chinese, North Indian
# ...

# %%
swiggy_HSR.shape
# Out:
# (18, 6)

# %%
swiggy_BTM = swiggy_df[swiggy_df['Location'].str.contains(r'BTM')]
swiggy_BTM
# Out:
#                                              Shop_Name  \
# 6    99 VARIETY DOSA AND PAV BHAJI- Malli Mane Food...
# 7                                      La Pino'z Pizza
# 10                                  Ambur Star Briyani
# 17                                   Sri Lakshmi Dhaba
# 20                   Just Bake - Cakes & confectioners
# 22                                      Hotel Godavari
# 25                                      Swad Punjab da
# 27                                       High N Hungry
# 31                                   Bengali Fun Foods
# 33                                           Oottupura
# 35                              Hyderabadi Biryani Hub
# 40                                Venu's Donne Biryani
# 42                                      Swadista Aahar
# 44                              Svadu Pure Ghee Sweets
# 45                                       Sai Abhiruchi
# 49                                        Balaji's Veg
# ...

# %%
swiggy_BTM.shape
# Out:
# (35, 6)

# %% [markdown]
# # Area Wise Analysis

# %% [markdown]
# 1)BTM

# %%
sns.histplot(swiggy_BTM['Rating'])
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Count'>

# %%
sns.histplot(swiggy_BTM['Cost_for_Two (in Rupees)'])
# Out:
# <AxesSubplot:xlabel='Cost_for_Two (in Rupees)', ylabel='Count'>

# %% [markdown]
# 2) HSR Area

# %%
sns.histplot(swiggy_HSR['Rating'])
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Count'>

# %%
sns.histplot(swiggy_HSR['Cost_for_Two (in Rupees)'])
# Out:
# <AxesSubplot:xlabel='Cost_for_Two (in Rupees)', ylabel='Count'>

# %% [markdown]
# Koramangala Area

# %%
sns.histplot(swiggy_Koramangala['Rating'])
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Count'>

# %%
sns.histplot(swiggy_Koramangala['Cost_for_Two (in Rupees)'])
# Out:
# <AxesSubplot:xlabel='Cost_for_Two (in Rupees)', ylabel='Count'>

# %% [raw]
# Conclusion: As we can see that the Area-wise Rating & Cost for Two varies as following:
#
# BTM : Most has 4.0 to 4.2 Rating and Approx. Cost for Two People lies between 200 to 350. (Max. Cost goes upto 600)
# HSR : Most has 4 or above Rating and Approx. Cost for Two People lies between 300 to 400. (Max. Cost goes upto 800)
# Koramangala : Most has 4.0 to 4.3 Rating and Approx. Cost for Two People lies between 200 to 350. (Max. Cost goes upto 600)
# With this we can conclude the Most Costly Area is HSR.

# %%
swiggy_df
# Out:
#               Shop_Name                                            Cuisine  \
# 0          Kanti Sweets                                             Sweets
# 1         Mumbai Tiffin             North Indian, Home Food, Thalis, Combo
# 2     Sri Krishna sagar  South Indian, North Indian, Fast Food, Beverag...
# 3               Al Daaz  American, Arabian, Chinese, Desserts, Fast Foo...
# 4         Beijing Bites                                      Chinese, Thai
# ..                  ...                                                ...
# 113  Wok Paper Scissors                          Pan-Asian, Chinese, Asian
# 114  Savoury Restaurant  Arabian, Middle Eastern, North Indian, Grill, ...
# 115         Royal Treat            North Indian, Chinese, Seafood, Biryani
# 116            Thali 99                                       North Indian
# 117  Mani's Dum Biryani                                    Andhra, Biryani
#
# ...

# %% [markdown]
# Most expensive restaurant

# %%
ind_most_expensive=swiggy_df['Cost_for_Two (in Rupees)'].sort_values(ascending=False).index[0]

# %%
ind_least_expensive = swiggy_df['Cost_for_Two (in Rupees)'].sort_values().index[0]

# %%
ind_least_expensive
# Out:
# 79

# %%
print("Most expensive shop: \n",swiggy_df.iloc[73,:])
# Out:
# Most expensive shop:
#  Shop_Name                   Punjabi Rasoi
# Cuisine                      North Indian
# Location                    Sector 3, HSR
# Rating                                4.0
# Cost_for_Two (in Rupees)              800
# City                                  HSR
# Name: 73, dtype: object

# %%
print("Least expensive shop: \n",swiggy_df.iloc[79,:])
# Out:
# Least expensive shop:
#  Shop_Name                                                   Tandoori Merchant
# Cuisine                     Andhra, Biryani, Chinese, Desserts, Fast Food,...
# Location                                                       4th Cross, BTM
# Rating                                                                    4.2
# Cost_for_Two (in Rupees)                                                  100
# City                                                                      BTM
# Name: 79, dtype: object

# %% [raw]
# Most and least Rated store

# %%
Highest_Rated_Restaurant = swiggy_df['Rating'].sort_values(ascending=False)

# %%
Highest_Rated_Restaurant [78]
# Out:
# 4.8

# %%
print("Most Rated Restaurant \n" , swiggy_df.iloc[78,:])
# Out:
# Most Rated Restaurant
#  Shop_Name                                Khichdi Experiment
# Cuisine                     Home Food, Healthy Food, Indian
# Location                           Koramangala, Koramangala
# Rating                                                  4.8
# Cost_for_Two (in Rupees)                                200
# City                                            Koramangala
# Name: 78, dtype: object

# %%
Least_Rated_Restaurant = swiggy_df['Rating'].sort_values(ascending=True)

# %%
Least_Rated_Restaurant[98]
# Out:
# 0.0

# %%
print("Least Rated Restaurant \n" , swiggy_df.iloc[98,:])
# Out:
# Least Rated Restaurant
#  Shop_Name                   Mandya Gowdru Donne Biryani
# Cuisine                                         Biryani
# Location                                       HSR, HSR
# Rating                                              0.0
# Cost_for_Two (in Rupees)                            350
# City                                                HSR
# Name: 98, dtype: object

# %% [markdown]
# Q. Analyze Affordable/Budgeted and Highest Rated Restaurants of Bangalore:

# %%
df_Affordable_Restaurants = swiggy_df[(swiggy_df['Cost_for_Two (in Rupees)'] <= 500) & (swiggy_df['Rating'] >= 4.0)]
df_Affordable_Restaurants
# Out:
#               Shop_Name                                            Cuisine  \
# 0          Kanti Sweets                                             Sweets
# 1         Mumbai Tiffin             North Indian, Home Food, Thalis, Combo
# 2     Sri Krishna sagar  South Indian, North Indian, Fast Food, Beverag...
# 3               Al Daaz  American, Arabian, Chinese, Desserts, Fast Foo...
# 4         Beijing Bites                                      Chinese, Thai
# ..                  ...                                                ...
# 110         Biryani Pot                              North Indian, Biryani
# 111             Bowl 99                         North Indian, South Indian
# 115         Royal Treat            North Indian, Chinese, Seafood, Biryani
# 116            Thali 99                                       North Indian
# 117  Mani's Dum Biryani                                    Andhra, Biryani
#
# ...

# %%
df_Affordable_Restaurants = df_Affordable_Restaurants.groupby(['Shop_Name', 'Rating'])['Cost_for_Two (in Rupees)'].agg('mean')
df_Affordable_Restaurants = df_Affordable_Restaurants.reset_index()
df_Affordable_Restaurants
# Out:
#                                             Shop_Name  Rating  \
# 0     99 VARIETY DOSA AND JUICE-Malli mane food court     4.1
# 1   99 VARIETY DOSA AND PAV BHAJI- Malli Mane Food...     4.1
# 2                           A2B - Adyar Ananda Bhavan     4.2
# 3                                     Abhiruchi Hotel     4.0
# 4                                             Al Daaz     4.4
# ..                                                ...     ...
# 76                               Venu's Donne Biryani     4.3
# 77                           WarmOven Cake & Desserts     4.1
# 78                                      World of asia     4.0
# 79                                  XO Belgian Waffle     4.3
# 80                            calicut cafe restaurant     4.1
#
#     Cost_for_Two (in Rupees)
# 0                        100
# 1                        200
# 2                        450
# 3                        250
# 4                        400
# ..                       ...
# ...

# %%
df_Affordable_Restaurants.sort_values(by = ['Rating'], ascending = False, inplace = True)
df_Affordable_Restaurants
# Out:
#                   Shop_Name  Rating  Cost_for_Two (in Rupees)
# 41       Khichdi Experiment     4.8                       200
# 54        Natural Ice Cream     4.6                       150
# 21   Corner House Ice Cream     4.6                       250
# 20              Chinese Bae     4.5                       450
# 50            Mumbai Tiffin     4.4                       400
# ..                      ...     ...                       ...
# 55      New Tasty Cafeteria     4.0                       350
# 53          Nandhana Palace     4.0                       500
# 52                  Nanda's     4.0                       400
# 45             Maa Di Hatti     4.0                       129
# 29  Gyaani Da Punjabi Dhaba     4.0                       500
#
# [81 rows x 3 columns]

# %%
plt.figure(figsize = (18, 7))
sns.barplot(x = df_Affordable_Restaurants['Shop_Name'], y = df_Affordable_Restaurants['Cost_for_Two (in Rupees)'],
           data = df_Affordable_Restaurants)
plt.title('Affordable/Budgeted and Highest Rated Restaurants ', fontsize = 14, fontweight = 'bold', 
          fontstyle = 'italic')
plt.xlabel('Shop_Name', fontsize = 10, fontweight = 'bold')
plt.xlabel('Approx. Cost_for_Two (₹)', fontsize = 10, fontweight = 'bold')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Cuisine Analysis

# %%
swiggy_df['Cuisine'] = swiggy_df['Cuisine']
swiggy_df['Cuisine']
# Out:
# 0                                                 Sweets
# 1                 North Indian, Home Food, Thalis, Combo
# 2      South Indian, North Indian, Fast Food, Beverag...
# 3      American, Arabian, Chinese, Desserts, Fast Foo...
# 4                                          Chinese, Thai
#                              ...
# 113                            Pan-Asian, Chinese, Asian
# 114    Arabian, Middle Eastern, North Indian, Grill, ...
# 115              North Indian, Chinese, Seafood, Biryani
# 116                                         North Indian
# 117                                      Andhra, Biryani
# Name: Cuisine, Length: 118, dtype: object

# %%
swiggy_df
# Out:
#               Shop_Name                                            Cuisine  \
# 0          Kanti Sweets                                             Sweets
# 1         Mumbai Tiffin             North Indian, Home Food, Thalis, Combo
# 2     Sri Krishna sagar  South Indian, North Indian, Fast Food, Beverag...
# 3               Al Daaz  American, Arabian, Chinese, Desserts, Fast Foo...
# 4         Beijing Bites                                      Chinese, Thai
# ..                  ...                                                ...
# 113  Wok Paper Scissors                          Pan-Asian, Chinese, Asian
# 114  Savoury Restaurant  Arabian, Middle Eastern, North Indian, Grill, ...
# 115         Royal Treat            North Indian, Chinese, Seafood, Biryani
# 116            Thali 99                                       North Indian
# 117  Mani's Dum Biryani                                    Andhra, Biryani
#
# ...

# %%
swiggy_df['Cuisine'].unique()
# Out:
# array(['Sweets', 'North Indian, Home Food, Thalis, Combo',
#        'South Indian, North Indian, Fast Food, Beverages, Jain',
#        'American, Arabian, Chinese, Desserts, Fast Food, Mughlai, North Indian',
#        'Chinese, Thai', 'North Indian',
#        'Fast Food, North Indian, Chinese', 'Italian',
#        'South Indian, Kerala, Chinese, North Indian',
#        'Pizzas, Italian, Mexican',
#        'Chinese, South Indian, North Indian, Desserts, Fast Food, Kerala, Andhra, Beverages, Mughlai, Seafood',
#        'Desserts', 'Chinese, Andhra, Biryani, Seafood', 'Chinese',
#        'South Indian, Chinese, Desserts, North Indian',
#        'Arabian, Fast Food', 'Desserts, Beverages', 'Indian, Rajasthani',
#        'Desserts, Bakery', 'Chinese, Healthy Food, North Indian',
#        'North Indian, Chinese, Hyderabadi', 'Fast Food',
#        'Chinese, Jain, North Indian, South Indian', 'Indian',
#        'North Indian, South Indian, Chinese',
# ...

# %%
freq_dict={}
for i in swiggy_df['Cuisine'].unique():
    Cuisines_Lists = i.split(',')
    for Cuisine in Cuisines_Lists:
        Cuisine = Cuisine.lstrip(' ')
        if Cuisine in freq_dict:
            freq_dict[Cuisine] = freq_dict[Cuisine] + 1
        else: 
            freq_dict[Cuisine] = 1
        
print(freq_dict)
print()
print('Total Records: \t', len(freq_dict))
# Out:
# {'Sweets': 2, 'North Indian': 32, 'Home Food': 2, 'Thalis': 1, 'Combo': 1, 'South Indian': 23, 'Fast Food': 16, 'Beverages': 9, 'Jain': 2, 'American': 8, 'Arabian': 4, 'Chinese': 35, 'Desserts': 15, 'Mughlai': 7, 'Thai': 2, 'Italian': 4, 'Kerala': 6, 'Pizzas': 5, 'Mexican': 3, 'Andhra': 12, 'Seafood': 8, 'Biryani': 18, 'Indian': 5, 'Rajasthani': 1, 'Bakery': 2, 'Healthy Food': 4, 'Hyderabadi': 5, 'Snacks': 4, 'Turkish': 2, 'Portuguese': 2, 'Chaat': 2, 'Asian': 3, 'Continental': 3, 'Mediterranean': 1, 'Lebanese': 1, 'Cafe': 2, 'Salads': 2, 'Pastas': 1, 'Punjabi': 2, 'Juices': 2, 'Kebabs': 2, 'Grill': 2, 'Ice Cream': 2, 'Tandoor': 1, 'Chettinad': 2, 'Pan-Asian': 2, 'Oriental': 1, 'Middle Eastern': 1}
#
# Total Records: 	 48

# %%
Cuisine = freq_dict.keys()
freq = freq_dict.values()

# %%
Cuisine_Analysis_df = pd.DataFrame()

# %%
Cuisine_Analysis_df['Cuisine'] = Cuisine
Cuisine_Analysis_df['Count'] = freq

# %%
Cuisine_Analysis_df
# Out:
#            Cuisine  Count
# 0           Sweets      2
# 1     North Indian     32
# 2        Home Food      2
# 3           Thalis      1
# 4            Combo      1
# 5     South Indian     23
# 6        Fast Food     16
# 7        Beverages      9
# 8             Jain      2
# 9         American      8
# 10         Arabian      4
# 11         Chinese     35
# 12        Desserts     15
# 13         Mughlai      7
# 14            Thai      2
# 15         Italian      4
# 16          Kerala      6
# 17          Pizzas      5
# 18         Mexican      3
# 19          Andhra     12
# 20         Seafood      8
# 21         Biryani     18
# 22          Indian      5
# 23      Rajasthani      1
# 24          Bakery      2
# 25    Healthy Food      4
# 26      Hyderabadi      5
# 27          Snacks      4
# 28         Turkish      2
# 29      Portuguese      2
# 30           Chaat      2
# 31           Asian      3
# 32     Continental      3
# 33   Mediterranean      1
# ...

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=Cuisine_Analysis_df,x='Cuisine',y='Count')
plt.xticks(rotation=90)
plt.title('Cuisines Overall Analysis ', fontsize = 14, fontweight = 'bold', fontstyle = 'italic')
plt.show()

# %%
swiggy_df.to_csv('C:/Users/Admin/Desktop/Raghav folder/I neuron Internshp/Cleaned swiggy Dataset.csv')
